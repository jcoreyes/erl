# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
x = np.load('training_buffer.npy')

# %%
len(x)
# Out:
# 11000

# %%
x
# Out:
# array([ {'subtracted': array([-0.08818966, -0.2510106 ,  0.4772588 , -1.12387323,  0.10081553,
#        -0.13692686,  0.1077268 ]), 'gravity': array([  3.61896642e-02,  -1.62209892e+01,  -2.92125893e+00,
#         -5.95612669e+00,   1.15918446e+00,   8.49268660e-02,
#          2.73194863e-04]), 'applied': array([ 1.        ,  0.5730194 ,  1.        ,  1.        ,  1.        ,
#        -0.57220215,  1.        ]), 'observed': array([  0.   , -16.524,  -2.336,  -7.036,   1.24 ,  -0.056,   0.104])},
#        {'subtracted': array([ 0.17575637, -0.41085729,  0.73734063, -1.30651271,  0.16095079,
#        -0.16920963,  0.08775671]), 'gravity': array([  3.62436324e-02,  -1.62251434e+01,  -2.92134070e+00,
#         -5.95748711e+00,   1.15904915e+00,   8.52096230e-02,
#          2.43289527e-04]), 'applied': array([ 1.        ,  0.46412409,  1.        ,  1.        ,  1.        ,
#         0.25739607,  1.        ]), 'observed': array([  0.476, -16.58 ,  -2.208,  -7.036,   1.412,  -0.076,   0.108])},
#        {'subtracted': array([ 0.11960725, -0.28560659,  0.64777303, -1.22577381,  0.19993889,
#        -0.14985703,  0.00384502]), 'gravity': array([  3.63927521e-02,  -1.62383938e+01,  -2.91977310e+00,
#         -5.97022629e+00,   1.16006112e+00,   8.58570337e-02,
#          1.54979542e-04]), 'applied': array([ 1.        ,  0.76798387,  1.        ,  1.        ,  1.        ,
#        -0.58620254, -1.        ]), 'observed': array([  0.424, -16.688,  -2.248,  -6.876,   1.28 ,  -0.032,   0.044])},
#        ...,
#        {'subtracted': array([  1.76602527e-01,  -6.05536044e-01,   7.28192449e-01,
#         -1.00709224e+00,   1.82753836e-04,  -1.06992103e-01,
#          4.03135922e-03]), 'gravity': array([  3.53974700e-02,  -1.60824642e+01,  -2.74019241e+00,
#         -5.89290762e+00,   1.15581727e+00,   9.49921012e-02,
#         -3.13592645e-05]), 'applied': array([ 0.04974442,  0.20126732,  0.52364594,  0.30700588, -0.1566902 ,
#         0.29495978,  0.58177817], dtype=float32), 'observed': array([  2.12000000e-01,  -1.66880000e+01,  -2.01200000e+00,
#         -6.90000000e+00,   1.15600000e+00,  -1.20000000e-02,
#          4.00000000e-03])},
#        {'subtracted': array([ 0.17660253, -0.60553604,  0.79219246, -0.8910923 ,  0.03218275,
#        -0.11899211,  0.01203136]), 'gravity': array([  3.53974700e-02,  -1.60824642e+01,  -2.74019241e+00,
#         -5.89290762e+00,   1.15581727e+00,   9.49921012e-02,
#         -3.13592645e-05]), 'applied': array([ 0.05044993,  0.20254993,  0.52487803,  0.30708972, -0.15729131,
#         0.29596242,  0.58301103], dtype=float32), 'observed': array([  2.64000000e-01,  -1.66360000e+01,  -1.90800000e+00,
#         -6.83200000e+00,   1.18400000e+00,  -6.40000000e-02,
#         -4.00000000e-03])},
#        {'subtracted': array([ 0.17660253, -0.55353606,  0.70419246, -0.91509229,  0.00818275,
#        -0.1309921 , -0.01196864]), 'gravity': array([  3.53974700e-02,  -1.60824642e+01,  -2.74019241e+00,
#         -5.89290762e+00,   1.15581727e+00,   9.49921012e-02,
#         -3.13592645e-05]), 'applied': array([ 0.04955209,  0.20269832,  0.52359247,  0.30657583, -0.15703394,
#         0.29587367,  0.58203143], dtype=float32), 'observed': array([  0.264, -16.744,  -1.992,  -6.876,   1.156,  -0.044,  -0.024])}], dtype=object)

# %%
subtracted = [val['subtracted'] for val in x]

# %%
gravity = [val['gravity'] for val in x]
applied = [val['applied'] for val in x]
observed = [val['observed'] for val in x]

# %%
plt.plot(gravity)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225e0ac0f0>,
#  <matplotlib.lines.Line2D at 0x7f225e0ac2b0>,
#  <matplotlib.lines.Line2D at 0x7f225e0ac470>,
#  <matplotlib.lines.Line2D at 0x7f225e0ac630>,
#  <matplotlib.lines.Line2D at 0x7f225e0ac7f0>,
#  <matplotlib.lines.Line2D at 0x7f225e0ac9b0>,
#  <matplotlib.lines.Line2D at 0x7f225e0acb70>]

# %%
plt.plot(observed)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225e235e80>,
#  <matplotlib.lines.Line2D at 0x7f225e23f080>,
#  <matplotlib.lines.Line2D at 0x7f225e23f240>,
#  <matplotlib.lines.Line2D at 0x7f225e23f400>,
#  <matplotlib.lines.Line2D at 0x7f225e23f5c0>,
#  <matplotlib.lines.Line2D at 0x7f225e23f780>,
#  <matplotlib.lines.Line2D at 0x7f225e23f940>]

# %%
plt.plot(applied)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225e1ac630>,
#  <matplotlib.lines.Line2D at 0x7f225e1ac7f0>,
#  <matplotlib.lines.Line2D at 0x7f225e1ac9b0>,
#  <matplotlib.lines.Line2D at 0x7f225e1acb70>,
#  <matplotlib.lines.Line2D at 0x7f225e1acd30>,
#  <matplotlib.lines.Line2D at 0x7f225e1acef0>,
#  <matplotlib.lines.Line2D at 0x7f225e1b10f0>]

# %%
plt.plot(subtracted)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225e1169b0>,
#  <matplotlib.lines.Line2D at 0x7f225e116b70>,
#  <matplotlib.lines.Line2D at 0x7f225e116d30>,
#  <matplotlib.lines.Line2D at 0x7f225e116ef0>,
#  <matplotlib.lines.Line2D at 0x7f225e11c0f0>,
#  <matplotlib.lines.Line2D at 0x7f225e11c2b0>,
#  <matplotlib.lines.Line2D at 0x7f225e11c470>]

# %%
def display_ith_joint_info(i, data):
    joint = [obs[i] for obs in data]
    plt.close()
    plt.plot(joint)
    plt.show()

# %%
display_ith_joint_info(1, subtracted)

# %%
data2 = np.load('buffer_with_pushes.npy')

# %%
subtracted = [val['subtracted'] for val in data2]
gravity = [val['gravity'] for val in data2]
applied = [val['applied'] for val in data2]
observed = [val['observed'] for val in data2]

# %%
plt.plot(observed)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225ee70978>,
#  <matplotlib.lines.Line2D at 0x7f225ee70c50>,
#  <matplotlib.lines.Line2D at 0x7f225ee70e48>,
#  <matplotlib.lines.Line2D at 0x7f225ee58080>,
#  <matplotlib.lines.Line2D at 0x7f225ee58278>,
#  <matplotlib.lines.Line2D at 0x7f225ee58470>,
#  <matplotlib.lines.Line2D at 0x7f225ee58668>]

# %%
plt.plot(subtracted)
# Out:
# [<matplotlib.lines.Line2D at 0x7f225e4590b8>,
#  <matplotlib.lines.Line2D at 0x7f225e459358>,
#  <matplotlib.lines.Line2D at 0x7f225e459550>,
#  <matplotlib.lines.Line2D at 0x7f225e459748>,
#  <matplotlib.lines.Line2D at 0x7f225e459940>,
#  <matplotlib.lines.Line2D at 0x7f225e459b38>,
#  <matplotlib.lines.Line2D at 0x7f225e459d30>]

# %%
display_ith_joint_info(5, subtracted)
