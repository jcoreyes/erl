# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.load('vibrations.npy')

# %%
len(data)
# Out:
# 2

# %%
len(data[0])
# Out:
# 0

# %%
def get_ith_joint_info(i, data):
    return [obs[i] for obs in data]
def display_ith_joint_info(i, data):
    joint = [obs[i] for obs in data]
    plt.close()
    plt.plot(joint)
    plt.show()

# %%
train = data[0]

# %%
reset = data[1]

# %%
data
# Out:
# array([], shape=(2, 0), dtype=float64)

# %%
train_applied = [ex['applied_torques'] for ex in train]

# %%
display_ith_joint_info(0, train_applied)

# %%
train_observed = [ex['observed_torques'] for ex in train]

# %%
display_ith_joint_info(0, train_observed)

# %%
delays = [ex['delay'] for ex in train]

# %%
plt.plot(delays)
plt.show()
